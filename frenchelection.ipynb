# %%
import pandas as pd

import plotly.plotly as py
import plotly.graph_objs as go

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

import main
import representatives
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # What if France had an Electoral College

# %% [markdown]
# ## loading election results

# %%
results = main.load_results()
results.head()
# Out:
#                          em_pct  mlp_pct  ff_pct  jlm_pct  bh_pct  nda_pct  \
# department
# Ain                       22.62    25.00   21.43    15.88    5.13     6.07
# Aisne                     17.94    35.67   16.30    16.99    4.24     5.08
# Allier                    23.72    22.34   18.94    19.91    5.52     5.09
# Alpes-de-Haute-Provence   20.02    24.53   18.49    22.51    5.00     4.87
# Hautes-Alpes              21.80    21.25   19.15    21.62    5.88     5.68
#
#                          jl_pct  pp_pct  fa_pct  na_pct  jc_pct winner
# department
# Ain                        1.06    0.95    1.11    0.57    0.18    mlp
# Aisne                      0.79    1.10    0.75    0.96    0.19    mlp
# Allier                     1.55    1.21    0.74    0.80    0.18     em
# Alpes-de-Haute-Provence    1.73    1.18    0.93    0.52    0.21    mlp
# Hautes-Alpes               1.85    1.21    0.90    0.47    0.19     em

# %% [markdown]
# first round results:

# %%
rawalloc = results.loc['Total', :]
rawalloc = rawalloc.rename(lambda nm: nm.replace('_pct', ''))
rawalloc = rawalloc[:-1]
rawalloc
# Out:
# em     24.01
# mlp     21.3
# ff     20.01
# jlm    19.58
# bh      6.36
# nda      4.7
# jl      1.21
# pp      1.09
# fa      0.92
# na      0.64
# jc      0.18
# Name: Total, dtype: object

# %%
results = results.drop('Total')
results = results.reset_index()

# %% [markdown]
# ## loading population statistics

# %%
population = main.load_population()
population.head()
# Out:
#          department  population
# 0              Nord     2595536
# 1             Paris     2229621
# 2  Bouches-du-Rhône     1993177
# 3             Rhône     1779845
# 4    Hauts-de-Seine     1591403

# %% [markdown]
# ## adding in electoral college votes

# %%
population.loc[:, 'num_sen'] = 2
reps = representatives.num_reps(
    population[['department', 'population']], regionColname='department'
)
population = population.merge(reps, on='department')
population.loc[:, 'evs'] = population.num_sen + population.num_reps
population.head()
# Out:
#          department  population  num_sen  num_reps   evs
# 0              Nord     2595536        2      35.0  37.0
# 1             Paris     2229621        2      30.0  32.0
# 2  Bouches-du-Rhône     1993177        2      26.0  28.0
# 3             Rhône     1779845        2      24.0  26.0
# 4    Hauts-de-Seine     1591403        2      21.0  23.0

# %% [markdown]
# ## assigning votes

# %%
tally = population.merge(results, on='department')
tally
# Out:
#                  department  population  num_sen  num_reps   evs  em_pct  \
# 0                      Nord     2595536        2      35.0  37.0   19.85
# 1                     Paris     2229621        2      30.0  32.0   34.83
# 2          Bouches-du-Rhône     1993177        2      26.0  28.0   19.37
# 3                     Rhône     1779845        2      24.0  26.0   26.58
# 4            Hauts-de-Seine     1591403        2      21.0  23.0   32.30
# 5         Seine-Saint-Denis     1552482        2      21.0  23.0   24.04
# 6                   Gironde     1505517        2      20.0  22.0   26.13
# 7             Pas-de-Calais     1465205        2      19.0  21.0   18.45
# 8                  Yvelines     1418484        2      19.0  21.0   28.86
# 9            Seine-et-Marne     1365200        2      18.0  20.0   23.11
# 10             Val-de-Marne     1354005        2      18.0  20.0   28.33
# 11         Loire-Atlantique     1328620        2      18.0  20.0   28.66
# 12            Haute-Garonne     1298562        2      17.0  19.0   26.43
# 13           Seine-Maritime     1254609        2      17.0  19.0   21.23
# 14                  Essonne     1253931        2      17.0  19.0   26.21
# 15                    Isère     1235387        2      16.0  18.0   24.77
# 16               Val-d'Oise     1194681        2      16.0  18.0   25.31
# 17                 Bas-Rhin     1109460        2      15.0  17.0   22.29
# 18                  Hérault     1092331        2      15.0  17.0   20.52
# 19          Alpes-Maritimes     1080771        2      14.0  16.0   19.04
# 20                  Moselle     1046873        2      14.0  16.0   21.05
# 21                      Var     1028583        2      14.0  16.0   17.73
# 22          Ille-et-Vilaine     1019923        2      14.0  16.0   30.26
# 23                Finistère      903921        2      12.0  14.0   29.45
# 24                     Oise      815400        2      11.0  13.0   19.80
# 25           Maine-et-Loire      800191        2      11.0  13.0   26.51
# 26             Haute-Savoie      769677        2      10.0  12.0   24.23
# 27                Haut-Rhin      758723        2      10.0  12.0   19.76
# 28                    Loire      756715        2      10.0  12.0   23.17
# 29                 Morbihan      737778        2      10.0  12.0   27.86
# ..                      ...         ...      ...       ...   ...     ...
# 69             Loir-et-Cher      332001        2       4.0   6.0   20.98
# 70                  Ardèche      320379        2       4.0   6.0   21.64
# 71                     Cher      311650        2       4.0   6.0   22.05
# 72                  Mayenne      307500        2       4.0   6.0   26.04
# 73                     Aube      306581        2       4.0   6.0   18.98
# 74                     Orne      288848        2       4.0   6.0   21.57
# 75                 Ardennes      280907        2       4.0   6.0   18.33
# 76                  Aveyron      277740        2       4.0   6.0   25.83
# 77                     Jura      260502        2       3.0   5.0   21.33
# 78          Tarn-et-Garonne      250342        2       3.0   5.0   20.65
# 79                  Corrèze      240781        2       3.0   5.0   26.93
# 80              Haute-Saône      238956        2       3.0   5.0   19.59
# 81          Hautes-Pyrénées      228868        2       3.0   5.0   25.11
# 82                    Indre      228091        2       3.0   5.0   20.85
# 83              Haute-Loire      226203        2       3.0   5.0   23.51
# 84                   Nièvre      215221        2       3.0   5.0   22.71
# 85                  Mayotte      212645        2       3.0   5.0   19.21
# 86                    Meuse      192094        2       3.0   5.0   19.35
# 87                     Gers      190276        2       3.0   5.0   23.40
# 88              Haute-Marne      181521        2       2.0   4.0   18.00
# 89                      Lot      173758        2       2.0   4.0   26.65
# 90              Haute-Corse      170974        2       2.0   4.0   19.02
# 91  Alpes-de-Haute-Provence      161916        2       2.0   4.0   20.02
# 92                   Ariège      152684        2       2.0   4.0   20.92
# 93             Corse-du-Sud      149234        2       2.0   4.0   17.87
# 94                   Cantal      147035        2       2.0   4.0   26.73
# 95    Territoire de Belfort      144318        2       2.0   4.0   20.64
# 96             Hautes-Alpes      139279        2       2.0   4.0   21.80
# 97                   Creuse      120872        2       2.0   4.0   22.50
# 98                   Lozère       76607        2       1.0   3.0   21.73
#
#     mlp_pct  ff_pct  jlm_pct  bh_pct  nda_pct  jl_pct  pp_pct  fa_pct  na_pct  \
# 0     28.22   16.75    21.28    5.65     4.82    0.63    0.97    0.85    0.81
# 1      4.99   26.45    19.56   10.18     1.67    0.51    0.63    0.77    0.27
# 2     27.28   19.76    22.02    4.53     3.85    0.96    0.76    0.90    0.39
# 3     16.26   23.16    19.70    6.76     4.33    0.75    0.80    1.03    0.46
# 4      7.64   29.14    18.28    7.19     2.69    0.60    0.63    1.06    0.31
# 5     13.59   12.76    34.02    8.41     3.07    0.58    1.12    1.61    0.60
# 6     18.26   17.08    21.85    7.56     4.18    1.93    1.56    0.82    0.47
# 7     34.35   14.29    19.13    5.17     4.97    0.70    1.08    0.66    1.04
# 8     12.92   27.25    16.65    6.93     4.34    0.71    0.72    1.07    0.38
# 9     22.85   17.77    20.84    5.70     6.10    0.76    0.93    1.20    0.54
# 10    11.50   20.21    24.53    7.77     4.32    0.65    0.86    1.20    0.45
# 11    13.70   19.68    21.98    8.03     4.50    0.74    1.19    0.76    0.59
# 12    16.71   16.49    23.69    8.37     3.87    2.01    0.99    0.83    0.44
# 13    24.90   17.24    22.20    6.05     4.81    0.64    1.21    0.76    0.78
# 14    16.43   18.04    21.88    6.75     7.18    0.72    0.92    1.21    0.47
# 15    22.33   17.05    20.52    6.59     5.10    0.99    0.96    0.99    0.54
# 16    17.18   18.45    23.96    6.84     4.52    0.73    0.92    1.41    0.50
# 17    24.70   22.00    14.78    5.34     6.57    1.07    1.09    1.14    0.81
# 18    25.70   17.60    22.97    5.77     3.69    1.35    0.90    0.94    0.40
# 19    27.75   27.39    14.96    3.58     4.28    0.90    0.62    1.03    0.29
# 20    28.35   17.17    17.90    5.27     5.82    1.03    1.25    1.07    0.88
# 21    30.43   24.87    15.38    3.44     4.76    1.13    0.76    0.96    0.37
# 22    14.12   19.03    19.70    8.91     4.48    0.76    1.18    0.67    0.72
# 23    13.89   17.94    19.67   10.91     4.08    1.11    1.48    0.66    0.65
# 24    30.88   17.54    17.68    4.69     5.47    0.78    1.07    1.07    0.84
# 25    16.98   23.73    17.06    6.44     5.52    0.76    1.24    0.75    0.84
# 26    18.84   25.41    16.22    5.27     5.99    1.12    1.03    1.21    0.46
# 27    27.16   22.34    14.32    4.63     7.07    1.24    1.17    1.29    0.77
# 28    24.08   18.36    18.75    5.80     5.80    1.29    1.05    0.89    0.65
# 29    17.69   20.88    17.49    7.33     4.78    1.03    1.35    0.69    0.70
# ..      ...     ...      ...     ...      ...     ...     ...     ...     ...
# 69    25.12   22.07    16.30    5.66     6.01    0.95    1.13    0.78    0.80
# 70    23.17   17.30    21.80    6.01     5.08    1.81    1.33    1.01    0.67
# 71    24.18   19.09    19.51    5.30     5.53    1.11    1.22    0.86    0.94
# 72    16.90   27.06    14.87    5.69     5.61    0.85    1.24    0.66    0.90
# 73    30.33   23.05    13.97    4.06     6.35    0.72    0.86    0.82    0.69
# 74    23.81   24.74    14.78    5.21     5.81    0.89    1.29    0.78    0.91
# 75    32.41   17.22    17.83    4.93     5.32    0.96    1.15    0.74    0.94
# 76    16.20   20.78    19.66    6.16     4.85    3.66    1.32    0.74    0.63
# 77    24.14   18.97    20.28    5.07     5.71    1.33    1.32    0.89    0.77
# 78    26.69   17.71    18.97    5.84     4.93    2.49    1.07    0.91    0.57
# 79    17.34   17.46    20.85    6.36     4.84    2.92    1.59    0.75    0.72
# 80    31.36   18.05    15.88    4.73     5.86    1.08    1.45    0.86    0.95
# 81    18.57   14.48    23.01    7.11     4.21    4.96    1.13    0.73    0.55
# 82    24.43   19.46    19.05    5.95     5.48    1.32    1.34    0.84    1.06
# 83    23.06   18.60    18.21    5.33     5.98    2.23    1.38    0.75    0.75
# 84    24.76   17.25    19.16    6.52     5.35    1.13    1.28    0.80    0.83
# 85    27.19   32.62     8.42    4.33     3.08    0.55    1.87    1.23    1.01
# 86    32.32   18.02    14.97    4.59     6.35    1.21    1.34    0.80    0.83
# 87    19.71   17.96    19.45    8.03     4.53    4.26    1.06    0.87    0.57
# 88    33.22   19.12    15.01    4.19     6.26    1.10    1.20    0.79    0.90
# 89    16.13   16.66    23.48    7.18     4.11    2.77    1.38    0.79    0.65
# 90    27.22   25.44    13.78    3.97     2.75    5.84    0.88    0.59    0.34
# 91    24.53   18.49    22.51    5.00     4.87    1.73    1.18    0.93    0.52
# 92    21.70   12.75    26.76    7.85     3.61    3.54    1.26    0.86    0.60
# 93    28.62   25.68    13.84    3.49     3.04    5.42    0.90    0.67    0.30
# 94    18.17   23.58    15.91    5.25     4.42    3.10    1.29    0.58    0.76
# 95    26.89   17.70    19.10    5.85     5.27    0.93    1.24    1.31    0.83
# 96    21.25   19.15    21.62    5.88     5.68    1.85    1.21    0.90    0.47
# 97    19.88   17.99    21.11    7.82     5.01    1.92    1.72    0.83    0.97
# 98    18.89   22.82    19.70    5.68     4.56    3.66    1.42    0.74    0.61
#
#     jc_pct winner
# 0     0.17    mlp
# 1     0.14     em
# 2     0.17    mlp
# 3     0.16     em
# 4     0.17     em
# 5     0.20    jlm
# 6     0.18     em
# 7     0.17    mlp
# 8     0.18     em
# 9     0.18     em
# 10    0.18     em
# 11    0.17     em
# 12    0.18     em
# 13    0.19    mlp
# 14    0.20     em
# 15    0.17     em
# 16    0.18     em
# 17    0.20    mlp
# 18    0.14    mlp
# 19    0.16    mlp
# 20    0.21    mlp
# 21    0.16    mlp
# 22    0.17     em
# 23    0.15     em
# 24    0.19    mlp
# 25    0.18     em
# 26    0.20     ff
# 27    0.25    mlp
# 28    0.17    mlp
# 29    0.19     em
# ..     ...    ...
# 69    0.21    mlp
# 70    0.19    mlp
# 71    0.20    mlp
# 72    0.18     ff
# 73    0.18    mlp
# 74    0.21     ff
# 75    0.18    mlp
# 76    0.18     em
# 77    0.19    mlp
# 78    0.18    mlp
# 79    0.23     em
# 80    0.19    mlp
# 81    0.14     em
# 82    0.23    mlp
# 83    0.20     em
# 84    0.19    mlp
# 85    0.49     ff
# 86    0.22    mlp
# 87    0.16     em
# 88    0.19    mlp
# 89    0.20     em
# 90    0.17    mlp
# 91    0.21    mlp
# 92    0.15    jlm
# 93    0.16    mlp
# 94    0.22     em
# 95    0.23    mlp
# 96    0.19     em
# 97    0.25     em
# 98    0.19     ff
#
# [99 rows x 17 columns]

# %% [markdown]
# electoral vote totals:

# %%
ectotal = tally.groupby('winner').evs.sum().sort_values(ascending=False)
ectotal
# Out:
# winner
# em     505.0
# mlp    474.0
# jlm     42.0
# ff      42.0
# Name: evs, dtype: float64

# %% [markdown]
# electoral vote percentages

# %%
ecalloc = ectotal / ectotal.sum() * 100

# %% [markdown]
# ## in pictures

# %% [markdown]
# the difference between true proportional allocation and electoral college allocation:

# %%
ecalloc
# Out:
# winner
# em     47.507056
# mlp    44.590781
# jlm     3.951082
# ff      3.951082
# Name: evs, dtype: float64

# %%
rawalloc
# Out:
# em     24.01
# mlp     21.3
# ff     20.01
# jlm    19.58
# bh      6.36
# nda      4.7
# jl      1.21
# pp      1.09
# fa      0.92
# na      0.64
# jc      0.18
# Name: Total, dtype: object

# %%
compalloc = pd.concat([rawalloc, ecalloc], axis=1)
compalloc.columns = ['true', 'electoral_college']
compalloc = compalloc.fillna(0)
compalloc = compalloc.sort_values(by='true', ascending=False)
compalloc = compalloc.rename({
    'em': 'Emmanuel Macron',
    'mlp': 'Marine Le Pen',
    'ff': 'François Fillon',
    'jlm': 'Jean-Luc Mélenchon',
    'bh': 'Benoît Hamon',
    'nda': 'Nicolas Dupont-Aignan',
    'jl': 'Jean Lassalle', 
    'pp': 'Philippe Poutou',
    'fa': 'François Asselineau',
    'na': 'Nathalie Arthaud',
    'jc': 'Jacques Cheminade',
})
compalloc
# Out:
#                         true  electoral_college
# Emmanuel Macron        24.01          47.507056
# Marine Le Pen          21.30          44.590781
# François Fillon        20.01           3.951082
# Jean-Luc Mélenchon     19.58           3.951082
# Benoît Hamon            6.36           0.000000
# Nicolas Dupont-Aignan   4.70           0.000000
# Jean Lassalle           1.21           0.000000
# Philippe Poutou         1.09           0.000000
# François Asselineau     0.92           0.000000
# Nathalie Arthaud        0.64           0.000000
# Jacques Cheminade       0.18           0.000000

# %%
x = compalloc.columns

data = [
    go.Bar(
        x=x,
        y=y,
        name=name
    )
    for (name, y) in compalloc.iterrows()
]

layout = go.Layout(barmode='stack', title='French Election Results')

fig = go.Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="91d6bb53-1fff-40fc-bfdd-291bf9d810f2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("91d6bb53-1fff-40fc-bfdd-291bf9d810f2", [{"type": "bar", "x": ["true", "electoral_college"], "y": [24.01, 47.50705550329257], "name": "Emmanuel Macron"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [21.3, 44.590780809031045], "name": "Marine Le Pen"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [20.01, 3.951081843838194], "name": "Fran\u00e7ois Fillon"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [19.58, 3.951081843838194], "name": "Jean-Luc M\u00e9lenchon"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [6.36, 0.0], "name": "Beno\u00eet Hamon"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [4.7, 0.0], "name": "Nicolas Dupont-Aignan"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [1.21, 0.0], "name": "Jean Lassalle"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [1.09, 0.0], "name": "Philippe Poutou"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [0.92, 0.0], "name": "Fran\u00e7ois Asselineau"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [0.64, 0.0], "name": "Nathalie Arthaud"}, {"type": "bar", "x": ["true", "electoral_college"], "y": [0.18, 0.0], "name": "Jacques Cheminade"}], {"barmode": "stack", "title": "French Election Results"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# The above item won't appear on github (run it in your own jupyter notebook session if you want to see it directly).
#
# In the meantime, I've uploaded [a version of it](https://plot.ly/~r.zach.lamberty/97/) to plotly -- check it out there.
